-- %%
SELECT * FROM bronze_dev.redfin.delistings_relistings_county LIMIT 100;


SELECT * FROM bronze_dev.census_bureau.american_community_survey_zcta LIMIT 100;



SELECT * FROM bronze_dev.opportunity_insights.social_capital_zip LIMIT 100;
