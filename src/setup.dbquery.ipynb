-- %%
--CREATE CATALOG real_estate;



CREATE SCHEMA IF NOT EXISTS bronze_dev.opportunity_insights;
CREATE SCHEMA IF NOT EXISTS bronze_dev.redfin;
CREATE SCHEMA IF NOT EXISTS bronze_dev.hud;



CREATE VOLUME IF NOT EXISTS bronze_dev.opportunity_insights.opportunity_insights_raw;
CREATE VOLUME IF NOT EXISTS bronze_dev.redfin.redfin_raw;
