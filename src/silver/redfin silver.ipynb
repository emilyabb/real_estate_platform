# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %sql
SELECT * FROM bronze_dev.redfin.price_drops_zipcode

# %%
# %sql
SELECT distinct frequency from bronze_dev.redfin.price_drops_zipcode;

# %%
import src.utils.helpers
from pyspark.sql import DataFrame
from pyspark.sql import functions as F
from pyspark.sql.types import DecimalType, IntegerType
type_map = (
    spark.read
    .option("header", True)
    .csv("/dbfs/tmp/redfin_schema.csv")
    .select("table_name", "column_name", "suggested_type")
    .collect()
)

type_map = {
    (r.table_name.lower(), r.column_name.lower()): r.suggested_type.lower()
    for r in type_map
}

type_map

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS silver_dev.redfin

# %%
import src.utils.helpers
df = spark.table("bronze_dev.redfin.price_drops_zipcode")
df_prepped = src.utils.helpers.prep_silver_df(df)
display(df_prepped)
